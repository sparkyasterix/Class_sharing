# %% [markdown]
# # •	We initially run the logistic regression by holding back 25% of data set for test set. This gives an AUC of 50% and 89.13% accuracy

# %%
# >0.098 in precipitation is considered rain in the HW

#import pandas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import roc_auc_score

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics

col_names = ['Date', 'Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature', 'Prcipitation','label']

# Load dataset
History = pd.read_csv("1_year_data.csv", header = None, names=col_names, skiprows=[0])

# Plot number of rainy days
ax = sns.countplot(x="label", data=History) # 

feature_cols = ['Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature']
X = History[feature_cols]
y = History.label

# Hold out Validation
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, y, test_size=0.25, random_state=2000)
logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train, Y_train)

y_pred = model.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test,y_pred))


auc = roc_auc_score(Y_test, y_pred)
print('AUC: %.3f' % auc)

confusion_matrix(Y_test, Y_pred)

# accuracry factors

def classifier_eval(pred, actual):
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    i = 0
    print(i)
    index = len(pred) #92
    for i in range(0, index):
        if pred[i] == 0 and actual[i] == 0:
            TP += 1
        elif pred[i] == 1 and actual[i] == 1:
            TN += 1
        elif pred[i] == 0 and actual[i] == 1:
            FP += 1
        elif pred[i] == 1 and actual[i] == 0:
            FN += 1

 

    accuracy = (TP + TN) / (TP + TN + FP + FN)
    precision = (TP) / (TP + FP)
    recall = (TP) / (TP + FN)
    true_positive_rate = (TP) / (TP + FN)
    false_positive_rate = (FP) / (TN + FP)
    return accuracy, precision, recall, true_positive_rate, false_positive_rate


from sklearn.linear_model import LogisticRegression


import numpy as np
Y_TEST = np.array(Y_test)
Y_TEST


total_metrics = {}
classifier_metrics = {}
accuracy, precision, recall, true_positive_rate, false_positive_rate = classifier_eval(y_pred, Y_TEST)
print("Accuracy: {}\nPrecision - TYPE 1 Error: {}\nRecall - TYPE 2 Error: {}\nTPR: {}\nFPR: {}".format(accuracy, precision, recall, true_positive_rate, false_positive_rate))


classifier_metrics['Accuracy'] = accuracy
classifier_metrics['Precision'] = precision
classifier_metrics['Recall'] = recall
classifier_metrics['TPR'] = true_positive_rate
classifier_metrics['FPR'] = false_positive_rate
total_metrics['Logistice Regression'] = classifier_metrics
classifier_metrics = {}
# Out:
# Accuracy: 0.8913043478260869
# AUC: 0.544
# 0
# Accuracy: 0.8913043478260869
# Precision - TYPE 1 Error: 0.9101123595505618
# Recall - TYPE 2 Error: 0.9759036144578314
# TPR: 0.9759036144578314
# FPR: 0.8888888888888888

# %%
# >0.098 in precipitation is considered rain in the HW
# converting to log scale increased the AUC to 50% from 48.1% and breaking the MinT,MaxT,WS into L,M,H categories improves the AUC +/-2%


# >0.098 in precipitation is considered rain in the HW

#import pandas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import roc_auc_score

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold

col_names = ['Date', 'Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature','MaxT','WS','WSF2','WSF5','WDF2','WDF5','WT02','WT08','Prcipitation','label']
# Load dataset
History = pd.read_csv("1_year_data_HW5.csv", header = None, names=col_names, skiprows=[0])

# Plot number of rainy days
ax = sns.countplot(x="label", data=History) # 

feature_cols = ['Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature']
#feature_cols = ['Thunder', 'Min_temperature', 'Average_temperature', 'MaxT','WS']
X = History[feature_cols]
y = History.label


# import the class
from sklearn.linear_model import LogisticRegression
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.25, random_state=2000)
X_test

# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter=1000)

# fit the model with data
logreg.fit(X_train,y_train)


y_pred = logreg.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))

confusion_matrix(y_test, y_pred)

auc = roc_auc_score(y_test, y_pred)
print('AUC: %.3f' % auc)

confusion_matrix(y_test, Y_pred)

# accuracry factors

def classifier_eval(pred, actual):
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    i = 0
    print(i)
    index = len(pred) #92
    for i in range(0, index):
        if pred[i] == 0 and actual[i] == 0:
            TP += 1
        elif pred[i] == 1 and actual[i] == 1:
            TN += 1
        elif pred[i] == 0 and actual[i] == 1:
            FP += 1
        elif pred[i] == 1 and actual[i] == 0:
            FN += 1

 

    accuracy = (TP + TN) / (TP + TN + FP + FN)
    precision = (TP) / (TP + FP)
    recall = (TP) / (TP + FN)
    true_positive_rate = (TP) / (TP + FN)
    false_positive_rate = (FP) / (TN + FP)
    return accuracy, precision, recall, true_positive_rate, false_positive_rate


from sklearn.linear_model import LogisticRegression


import numpy as np
Y_TEST = np.array(y_test)
Y_TEST


total_metrics = {}
classifier_metrics = {}
accuracy, precision, recall, true_positive_rate, false_positive_rate = classifier_eval(y_pred, Y_TEST)
print("Accuracy: {}\nPrecision - TYPE 1 Error: {}\nRecall - TYPE 2 Error: {}\nTPR: {}\nFPR: {}".format(accuracy, precision, recall, true_positive_rate, false_positive_rate))


classifier_metrics['Accuracy'] = accuracy
classifier_metrics['Precision'] = precision
classifier_metrics['Recall'] = recall
classifier_metrics['TPR'] = true_positive_rate
classifier_metrics['FPR'] = false_positive_rate
total_metrics['Logistice Regression'] = classifier_metrics
classifier_metrics = {}
# Out:
# Accuracy: 0.8478260869565217
# AUC: 0.500
# 0
# Accuracy: 0.8478260869565217
# Precision - TYPE 1 Error: 0.8478260869565217
# Recall - TYPE 2 Error: 1.0
# TPR: 1.0
# FPR: 1.0

# %% [markdown]
# # •	Next we tried to convert all the metrics to log scale for temperature and wind speed and we tried to bucket the wind speed and max temperature into low, medium and high categories
#
# #Adding multiple metrics like snow fall didn’t change the accuracy or AUC
# #Doing this also didn’t improve the AUC and accuracy

# %%
col_names = ['Date', 'Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature','MaxT','WS','WSF2','WSF5','WDF2','WDF5','WT02','WT08','Prcipitation','label']
# Load dataset
History = pd.read_csv("1_year_data_HW5.csv", header = None, names=col_names, skiprows=[0])

# Plot number of rainy days
ax = sns.countplot(x="label", data=History) # 

#feature_cols = ['Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature', 'MT']
feature_cols = ['Thunder', 'Min_temperature', 'Average_temperature', 'MaxT','WS']
X = History[feature_cols]
y = History.label


# import the class
from sklearn.linear_model import LogisticRegression
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.25, random_state=2000)
X_test

# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter=1000)

# fit the model with data
logreg.fit(X_train,y_train)


y_pred = logreg.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))

confusion_matrix(y_test, y_pred)

auc = roc_auc_score(Y_test, y_pred)
print('AUC: %.3f' % auc)

confusion_matrix(Y_test, y_pred)


def classifier_eval(pred, actual):
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    i = 0
    print(i)
    index = len(pred) #92
    for i in range(0, index):
        if pred[i] == 0 and actual[i] == 0:
            TP += 1
        elif pred[i] == 1 and actual[i] == 1:
            TN += 1
        elif pred[i] == 0 and actual[i] == 1:
            FP += 1
        elif pred[i] == 1 and actual[i] == 0:
            FN += 1

 

    accuracy = (TP + TN) / (TP + TN + FP + FN)
    precision = (TP) / (TP + FP)
    recall = (TP) / (TP + FN)
    true_positive_rate = (TP) / (TP + FN)
    false_positive_rate = (FP) / (TN + FP)
    return accuracy, precision, recall, true_positive_rate, false_positive_rate


from sklearn.linear_model import LogisticRegression


import numpy as np
Y_TEST = np.array(y_test)
Y_TEST


total_metrics = {}
classifier_metrics = {}
accuracy, precision, recall, true_positive_rate, false_positive_rate = classifier_eval(y_pred, Y_TEST)
print("Accuracy: {}\nPrecision - TYPE 1 Error: {}\nRecall - TYPE 2 Error: {}\nTPR: {}\nFPR: {}".format(accuracy, precision, recall, true_positive_rate, false_positive_rate))


classifier_metrics['Accuracy'] = accuracy
classifier_metrics['Precision'] = precision
classifier_metrics['Recall'] = recall
classifier_metrics['TPR'] = true_positive_rate
classifier_metrics['FPR'] = false_positive_rate
total_metrics['Logistice Regression'] = classifier_metrics
classifier_metrics = {}
# Out:
# Accuracy: 0.8478260869565217
# AUC: 0.500
# 0
# Accuracy: 0.8478260869565217
# Precision - TYPE 1 Error: 0.8478260869565217
# Recall - TYPE 2 Error: 1.0
# TPR: 1.0
# FPR: 1.0

# %% [markdown]
# # •	For the same dataset we tried to update the classification of rain definition by reducing it to >0.01 precipitation
# o	Doing above doesnt improves the AUC (53.7%), but it reduced the accuracy down to 70%

# %%
col_names = ['Date', 'Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature','MaxT','WS','WSF2','WSF5','WDF2','WDF5','WT02','WT08','Prcipitation','label']
# Load dataset
History = pd.read_csv("1_year_data_HW5.csv", header = None, names=col_names, skiprows=[0])

# Plot number of rainy days
ax = sns.countplot(x="label", data=History) # 

#feature_cols = ['Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature', 'MT']
feature_cols = ['Thunder', 'Min_temperature', 'Average_temperature', 'MaxT','WS']
X = History[feature_cols]
y = History.label


# import the class
from sklearn.linear_model import LogisticRegression
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.25, random_state=2000)
X_test

# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter=1000)

# fit the model with data
logreg.fit(X_train,y_train)


y_pred = logreg.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))

confusion_matrix(y_test, y_pred)

auc = roc_auc_score(Y_test, y_pred)
print('AUC: %.3f' % auc)

confusion_matrix(Y_test, y_pred)


def classifier_eval(pred, actual):
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    i = 0
    print(i)
    index = len(pred) #92
    for i in range(0, index):
        if pred[i] == 0 and actual[i] == 0:
            TP += 1
        elif pred[i] == 1 and actual[i] == 1:
            TN += 1
        elif pred[i] == 0 and actual[i] == 1:
            FP += 1
        elif pred[i] == 1 and actual[i] == 0:
            FN += 1

 

    accuracy = (TP + TN) / (TP + TN + FP + FN)
    precision = (TP) / (TP + FP)
    recall = (TP) / (TP + FN)
    true_positive_rate = (TP) / (TP + FN)
    false_positive_rate = (FP) / (TN + FP)
    return accuracy, precision, recall, true_positive_rate, false_positive_rate


from sklearn.linear_model import LogisticRegression


import numpy as np
Y_TEST = np.array(y_test)
Y_TEST


total_metrics = {}
classifier_metrics = {}
accuracy, precision, recall, true_positive_rate, false_positive_rate = classifier_eval(y_pred, Y_TEST)
print("Accuracy: {}\nPrecision - TYPE 1 Error: {}\nRecall - TYPE 2 Error: {}\nTPR: {}\nFPR: {}".format(accuracy, precision, recall, true_positive_rate, false_positive_rate))


classifier_metrics['Accuracy'] = accuracy
classifier_metrics['Precision'] = precision
classifier_metrics['Recall'] = recall
classifier_metrics['TPR'] = true_positive_rate
classifier_metrics['FPR'] = false_positive_rate
total_metrics['Logistice Regression'] = classifier_metrics
classifier_metrics = {}
# Out:
# Accuracy: 0.75
# AUC: 0.537
# 0
# Accuracy: 0.75
# Precision - TYPE 1 Error: 0.75
# Recall - TYPE 2 Error: 0.9850746268656716
# TPR: 0.9850746268656716
# FPR: 0.88

# %% [markdown]
# # Adding bogus basin snow days
# •	For the above dataset, now we added rainy days in Nampa and removed the snow days in bogus basin, as it wasn’t giving us better accurarcy
# o	Doing above improved the AUC to 67% and brought back the accuracy close to 80%
# o	This has also improved our precision value to 10/25=40%, which was previously 12.5%

# %%
#import pandas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import roc_auc_score

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold

col_names = ['Date', 'Average_temperature','BB_SNOW', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature','MaxT','WS','WSF2','WSF5','WDF2','WDF5','WT02','WT08','Prcipitation','label']
# Load dataset
History = pd.read_csv("1_year_data_HW5_adjacent_city.csv", header = None, names=col_names, skiprows=[0])

# Plot number of rainy days
ax = sns.countplot(x="label", data=History) # 

#feature_cols = ['Average_temperature', 'Wind_speed', 'Thunder', 'Max_temperature', 'Min_temperature', 'MT']
feature_cols = ['BB_SNOW','Thunder', 'Min_temperature', 'Average_temperature', 'MaxT','WS']
X = History[feature_cols]
y = History.label


# import the class
from sklearn.linear_model import LogisticRegression
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.25, random_state=2000)
X_test

# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter=1000)

# fit the model with data
logreg.fit(X_train,y_train)


y_pred = logreg.predict(X_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test,y_pred))

confusion_matrix(y_test, y_pred)

auc = roc_auc_score(y_test, y_pred)
print('AUC: %.3f' % auc)

confusion_matrix(y_test, y_pred)

def classifier_eval(pred, actual):
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    i = 0
    print(i)
    index = len(pred) #92
    for i in range(0, index):
        if pred[i] == 0 and actual[i] == 0:
            TP += 1
        elif pred[i] == 1 and actual[i] == 1:
            TN += 1
        elif pred[i] == 0 and actual[i] == 1:
            FP += 1
        elif pred[i] == 1 and actual[i] == 0:
            FN += 1

 

    accuracy = (TP + TN) / (TP + TN + FP + FN)
    precision = (TP) / (TP + FP)
    recall = (TP) / (TP + FN)
    true_positive_rate = (TP) / (TP + FN)
    false_positive_rate = (FP) / (TN + FP)
    return accuracy, precision, recall, true_positive_rate, false_positive_rate


from sklearn.linear_model import LogisticRegression


import numpy as np
Y_TEST = np.array(y_test)
Y_TEST


total_metrics = {}
classifier_metrics = {}
accuracy, precision, recall, true_positive_rate, false_positive_rate = classifier_eval(y_pred, Y_TEST)
print("Accuracy: {}\nPrecision - TYPE 1 Error: {}\nRecall - TYPE 2 Error: {}\nTPR: {}\nFPR: {}".format(accuracy, precision, recall, true_positive_rate, false_positive_rate))


classifier_metrics['Accuracy'] = accuracy
classifier_metrics['Precision'] = precision
classifier_metrics['Recall'] = recall
classifier_metrics['TPR'] = true_positive_rate
classifier_metrics['FPR'] = false_positive_rate
total_metrics['Logistice Regression'] = classifier_metrics
classifier_metrics = {}
# Out:
# Accuracy: 0.7934782608695652
# AUC: 0.670
# 0
# Accuracy: 0.7934782608695652
# Precision - TYPE 1 Error: 0.8076923076923077
# Recall - TYPE 2 Error: 0.9402985074626866
# TPR: 0.9402985074626866
# FPR: 0.6

# %% [markdown]
# #

# %%
# K fold validation

kfold = model_selection.KFold(n_splits=10)
model_kfold = LogisticRegression(max_iter=1000)
results_kfold = model_selection.cross_val_score(model_kfold, X, y, cv=kfold)
Y_pred = logreg.predict(X_test)
print("Accuracy: %.2f%%" % (results_kfold.mean()*100.0))
# Out:
# Accuracy: 70.73%

# %%
skfold = StratifiedKFold(n_splits=3)
model_skfold = LogisticRegression(max_iter=1000)
results_skfold = model_selection.cross_val_score(model_skfold, X, y, cv=skfold)
print("Accuracy: %.2f%%" % (results_skfold.mean()*100.0))
# Out:
# Accuracy: 75.62%

# %%
# LOCOV
loocv = model_selection.LeaveOneOut()
model_loocv = LogisticRegression(max_iter=1000)
results_loocv = model_selection.cross_val_score(model_loocv, X, y, cv=loocv)
print("Accuracy: %.2f%%" % (results_loocv.mean()*100.0))
# Out:
# Accuracy: 78.63%

# %%
#Repeated Random Test-Train Splits
kfold2 = model_selection.ShuffleSplit(n_splits=10, test_size=0.30, random_state=100)
model_shufflecv = LogisticRegression(max_iter=1000)
results_4 = model_selection.cross_val_score(model_shufflecv, X, y, cv=kfold2)
print("Accuracy: %.2f%% (%.2f%%)" % (results_4.mean()*100.0, results_4.std()*100.0))
# Out:
# Accuracy: 79.27% (1.62%)
